# %% [markdown]
# # 0. Data Importing from kaggle

# %%
import os
from tqdm.notebook import tqdm
for dirname, _, filenames in tqdm(os.walk('/kaggle/input')):
    for filename in filenames:
        os.path.join(dirname, filename)
#         print(os.path.join(dirname, filename))
# Out:
# 0it [00:00, ?it/s]

# %% [markdown]
# # Limiting GPU usage

# %%
# limit memory to prevent data leak
import tensorflow as tf
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    
    del logical_gpus,gpus
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# 2 Physical GPUs, 2 Logical GPUs

# %% [markdown]
# # 1. Importing modules

# %%
import numpy as np
import pandas as pd
import json
import gc
import matplotlib.pyplot as plt
# %matplotlib inline
from glob import glob
import os
train_files = glob("../input/quickdraw-doodle-recognition/train_simplified/*.csv")

# calculating data size per category
rows = 200000
# rows = 10000
rows = rows - (rows % 340)
cat_size = rows // 340
print(cat_size)
gc.collect()
# Out:
# 588
# 56

# %% [markdown]
# # 2. Image Preprocessing
# 1. converting data in text json to an image
# 2. normalizing the image size
# 3. normalizing the image pixels

# %%
from PIL import Image, ImageDraw
from dask import bag
def drawStrokes(matrixOfStrokes):
    image = Image.new("RGB", (256,256), color=255)
    image_draw = ImageDraw.Draw(image)
    for stroke in json.loads(matrixOfStrokes):
        for i in range(len(stroke[0])-1):
            image_draw.line([stroke[0][i], 
                             stroke[1][i],
                             stroke[0][i+1], 
                             stroke[1][i+1]],
                            fill=0, width=5)
    return np.array(image.resize((32,32)))/255.

# %%
from tqdm.notebook import tqdm
X = np.zeros((rows,32,32,3))
categories = pd.Series([None] * rows)
i = 0
for f in tqdm(train_files):
    for df in pd.read_csv(f, index_col="key_id", chunksize=1000, nrows=cat_size):
        df = df.drop(['countrycode','timestamp','recognized'],axis=1)
        imagebag = bag.from_sequence(df.drawing.values).map(drawStrokes)
        imagebag = np.array(imagebag.compute())
        categories[i:(i + imagebag.shape[0])] = df["word"].replace("\s+", "_", regex=True)
        X[i:(i + imagebag.shape[0])] = imagebag
        i += imagebag.shape[0]
# Out:
#   0%|          | 0/340 [00:00<?, ?it/s]

# %%
gc.collect()
# Out:
# 39

# %%
categories.value_counts()
# Out:
# traffic_light    588
# umbrella         588
# house            588
# trombone         588
# paper_clip       588
#                 ...
# rain             588
# rabbit           588
# lantern          588
# toaster          588
# fish             588
# Length: 340, dtype: int64

# %% [markdown]
# # 3. Train Test split

# %%
from sklearn.model_selection import train_test_split
Y = pd.get_dummies(categories)
tr_x,tst_x,tr_Y,tst_Y = train_test_split(X, Y, test_size=0.25,random_state=0,stratify=Y)

# %%
itr = 0
for df in tr_Y:
    print(f"{df} : {tr_Y[df].value_counts()[1]}")
    if itr == 5:
        break
    else:
        itr+= 1
# Out:
# The_Eiffel_Tower : 441
# The_Great_Wall_of_China : 441
# The_Mona_Lisa : 441
# airplane : 441
# alarm_clock : 441
# ambulance : 441

# %%
itr = 0
for df in tst_Y:
    try:
        print(f"{df} : {tst_Y[df].value_counts()[1]}")
    except:
        print(f"{df} : 0")
        
    if itr == 5:
        break
    else:
        itr+= 1
# Out:
# The_Eiffel_Tower : 147
# The_Great_Wall_of_China : 147
# The_Mona_Lisa : 147
# airplane : 147
# alarm_clock : 147
# ambulance : 147

# %%
del X,categories
gc.collect()
# Out:
# 21

# %% [markdown]
# # 4. Creating Deep learning model
#
# - try adding more Dense layers
# - try removing regularization

# %%
from keras.callbacks import ModelCheckpoint
# from tensorflow.keras.optimizers.legacy import Adam

filepath = 'my_best_model.hdf5'

checkpoint = ModelCheckpoint(filepath=filepath, 
                             monitor="val_loss", 
                             save_best_only=True,
                             mode='min')

# %%
from keras.callbacks import EarlyStopping
earlystop= EarlyStopping(monitor='val_accuracy', patience=6)

# %%
callbacks = [checkpoint,earlystop]

# %%
gc.collect()
# Out:
# 84

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import *
from tensorflow.keras import regularizers

strategy = tf.distribute.MirroredStrategy()
with strategy.scope():
    
    model = Sequential()

#     model.add(Conv2D(32, (3,3), activation = 'relu', padding = 'same', input_shape=(32, 32, 3)))
#     model.add(Conv2D(32, (3,3), activation = 'relu', padding = 'same'))
#     model.add(MaxPooling2D(2,2))
#     model.add(Dropout(0.25))
#     model.add(BatchNormalization())
    
    model.add(Conv2D(64, (3,3), activation = 'relu', padding = 'same',input_shape=(32,32,3)))
    model.add(Conv2D(64, (3,3), activation = 'relu', padding = 'same'))
    model.add(MaxPooling2D(2,2))
    model.add(Dropout(0.25))
    model.add(BatchNormalization())
    
    model.add(Conv2D(128, (3,3), activation = 'relu', padding = 'same'))
    model.add(Conv2D(128, (3,3), activation = 'relu', padding = 'same'))
    model.add(MaxPooling2D(2,2))
    model.add(Dropout(0.25))
    model.add(BatchNormalization())

    model.add(Conv2D(256, (3,3), activation = 'relu', padding = 'same'))
    model.add(Conv2D(256, (3,3), activation = 'relu', padding = 'same'))
    model.add(MaxPooling2D(2,2))
    model.add(Dropout(0.25))
    model.add(BatchNormalization())

    model.add(Conv2D(512, (3,3), activation = 'relu', padding = 'same'))
    model.add(Conv2D(512, (3,3), activation = 'relu', padding = 'same'))
    model.add(MaxPooling2D(2,2))
    model.add(Dropout(0.25))
    model.add(BatchNormalization())

    model.add(Conv2D(1024, (3,3), activation = 'relu', padding = 'same'))
    model.add(Conv2D(1024, (3,3), activation = 'relu', padding = 'same'))
    model.add(MaxPooling2D(2,2))
    model.add(BatchNormalization())
    model.add(Flatten())

    
    model.add(Dense(1024, activation='relu',kernel_regularizer=regularizers.l2(0.05)))
#     model.add(Dense(1024, activation='relu'))
    model.add(Dropout(0.5))
    model.add(BatchNormalization())

#     model.add(Dense(512, activation='relu'))
    model.add(Dense(512, activation='relu',kernel_regularizer=regularizers.l2(0.01)))
    model.add(Dropout(0.25))
    model.add(BatchNormalization())

    model.add(Dense(340, activation='softmax'))
    
    model.compile(loss='categorical_crossentropy',
              optimizer= "adam",
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 64)        1792
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 64)        36928
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 64)       0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 64)        0
#
#  batch_normalization (BatchN  (None, 16, 16, 64)       256
#  ormalization)
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 128)       73856
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 128)       147584
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 128)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 128)         0
#
#  batch_normalization_1 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 256)         295168
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 256)         590080
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 256)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 256)         0
#
#  batch_normalization_2 (Batc  (None, 4, 4, 256)        1024
#  hNormalization)
#
#  conv2d_6 (Conv2D)           (None, 4, 4, 512)         1180160
#
#  conv2d_7 (Conv2D)           (None, 4, 4, 512)         2359808
#
#  max_pooling2d_3 (MaxPooling  (None, 2, 2, 512)        0
#  2D)
#
#  dropout_3 (Dropout)         (None, 2, 2, 512)         0
#
#  batch_normalization_3 (Batc  (None, 2, 2, 512)        2048
#  hNormalization)
#
#  conv2d_8 (Conv2D)           (None, 2, 2, 1024)        4719616
#
#  conv2d_9 (Conv2D)           (None, 2, 2, 1024)        9438208
#
#  max_pooling2d_4 (MaxPooling  (None, 1, 1, 1024)       0
#  2D)
#
#  batch_normalization_4 (Batc  (None, 1, 1, 1024)       4096
#  hNormalization)
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 1024)              1049600
#
#  dropout_4 (Dropout)         (None, 1024)              0
#
#  batch_normalization_5 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  batch_normalization_6 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_2 (Dense)             (None, 340)               174420
#
# =================================================================
# Total params: 20,606,100
# Trainable params: 20,599,060
# Non-trainable params: 7,040
# _________________________________________________________________

# %%
gc.collect()
# Out:
# 486

# %% [markdown]
# # 6. Data Augmentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

batch_size = 200
aug = ImageDataGenerator(
        rotation_range=20,
        zoom_range=0.15,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.15,
        horizontal_flip=True,
        fill_mode="nearest")

# %% [markdown]
# # 5. Training Deep learning model

# %% [markdown]
# RUN 1

# %%
# history = model.fit(tr_x, tr_Y,batch_size=200,epochs=200
#           ,validation_data=(tst_x,tst_Y),callbacks=callbacks)

# history = model.fit(tr_x, tr_Y,batch_size=128,epochs=30
#           ,validation_data=(tst_x,tst_Y))

# history = model.fit(
#     x=aug.flow(tr_x, tr_Y, batch_size=batch_size),
#     validation_data=(tst_x,tst_Y),
#     epochs=30,
#     callbacks=callbacks)

history = model.fit(
    x=aug.flow(tr_x, tr_Y, batch_size=batch_size),
    validation_data=(tst_x,tst_Y),
    epochs=200,
    callbacks=callbacks)

print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.grid()
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.grid()
plt.show()


# plt.plot(history.history['accuracy'])
# plt.plot(history.history['val_accuracy'])
# plt.title('model accuracy')
# plt.ylabel('accuracy')
# plt.xlabel('epoch')
# plt.legend(['train', 'val'], loc='upper left')
# plt.show()
# Out:
# Epoch 1/200
# 2023-04-01 08:08:49.758553: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 750/750 [==============================] - 168s 186ms/step - loss: 8.3766 - accuracy: 0.0127 - val_loss: 7.8878 - val_accuracy: 0.0047
# Epoch 2/200
# 750/750 [==============================] - 133s 177ms/step - loss: 5.5526 - accuracy: 0.0375 - val_loss: 5.2517 - val_accuracy: 0.0574
# Epoch 3/200
# 750/750 [==============================] - 132s 176ms/step - loss: 5.0765 - accuracy: 0.0831 - val_loss: 4.5905 - val_accuracy: 0.1413
# Epoch 4/200
# 750/750 [==============================] - 134s 178ms/step - loss: 4.7387 - accuracy: 0.1344 - val_loss: 5.2770 - val_accuracy: 0.1243
# Epoch 5/200
# 750/750 [==============================] - 132s 176ms/step - loss: 4.4606 - accuracy: 0.1812 - val_loss: 3.9732 - val_accuracy: 0.2637
# Epoch 6/200
# 750/750 [==============================] - 134s 179ms/step - loss: 4.2468 - accuracy: 0.2161 - val_loss: 3.7682 - val_accuracy: 0.3047
# Epoch 7/200
# 750/750 [==============================] - 133s 177ms/step - loss: 4.0764 - accuracy: 0.2452 - val_loss: 3.5721 - val_accuracy: 0.3415
# Epoch 8/200
# 750/750 [==============================] - 130s 174ms/step - loss: 3.9193 - accuracy: 0.2737 - val_loss: 3.3721 - val_accuracy: 0.3818
# Epoch 9/200
# 750/750 [==============================] - 131s 174ms/step - loss: 3.7739 - accuracy: 0.2989 - val_loss: 3.2827 - val_accuracy: 0.3930
# Epoch 10/200
# 750/750 [==============================] - 131s 175ms/step - loss: 3.6440 - accuracy: 0.3208 - val_loss: 3.2933 - val_accuracy: 0.3898
# Epoch 11/200
# 750/750 [==============================] - 130s 173ms/step - loss: 3.5253 - accuracy: 0.3379 - val_loss: 2.9763 - val_accuracy: 0.4482
# Epoch 12/200
# 750/750 [==============================] - 134s 178ms/step - loss: 3.4321 - accuracy: 0.3562 - val_loss: 2.8984 - val_accuracy: 0.4620
# Epoch 13/200
# 750/750 [==============================] - 130s 173ms/step - loss: 3.3438 - accuracy: 0.3709 - val_loss: 2.8116 - val_accuracy: 0.4789
# Epoch 14/200
# 750/750 [==============================] - 132s 176ms/step - loss: 3.2865 - accuracy: 0.3845 - val_loss: 2.7327 - val_accuracy: 0.4990
# Epoch 15/200
# 750/750 [==============================] - 129s 172ms/step - loss: 3.2231 - accuracy: 0.3964 - val_loss: 2.7093 - val_accuracy: 0.5034
# Epoch 16/200
# 750/750 [==============================] - 131s 174ms/step - loss: 3.1730 - accuracy: 0.4074 - val_loss: 2.6189 - val_accuracy: 0.5167
# Epoch 17/200
# 750/750 [==============================] - 130s 173ms/step - loss: 3.1175 - accuracy: 0.4171 - val_loss: 2.6277 - val_accuracy: 0.5181
# Epoch 18/200
# 750/750 [==============================] - 135s 179ms/step - loss: 3.0712 - accuracy: 0.4258 - val_loss: 2.5398 - val_accuracy: 0.5319
# Epoch 19/200
# 750/750 [==============================] - 134s 178ms/step - loss: 3.0366 - accuracy: 0.4320 - val_loss: 2.4947 - val_accuracy: 0.5470
# Epoch 20/200
# 750/750 [==============================] - 132s 175ms/step - loss: 2.9958 - accuracy: 0.4402 - val_loss: 2.4675 - val_accuracy: 0.5547
# Epoch 21/200
# 750/750 [==============================] - 134s 178ms/step - loss: 2.9646 - accuracy: 0.4489 - val_loss: 2.4623 - val_accuracy: 0.5570
# Epoch 22/200
# 750/750 [==============================] - 134s 179ms/step - loss: 2.9369 - accuracy: 0.4535 - val_loss: 2.4104 - val_accuracy: 0.5646
# Epoch 23/200
# 750/750 [==============================] - 133s 177ms/step - loss: 2.8968 - accuracy: 0.4614 - val_loss: 2.4017 - val_accuracy: 0.5637
# Epoch 24/200
# 750/750 [==============================] - 130s 173ms/step - loss: 2.8725 - accuracy: 0.4655 - val_loss: 2.4292 - val_accuracy: 0.5633
# Epoch 25/200
# 750/750 [==============================] - 134s 179ms/step - loss: 2.8436 - accuracy: 0.4720 - val_loss: 2.3482 - val_accuracy: 0.5820
# Epoch 26/200
# 750/750 [==============================] - 129s 173ms/step - loss: 2.8293 - accuracy: 0.4755 - val_loss: 2.3577 - val_accuracy: 0.5785
# Epoch 27/200
# 750/750 [==============================] - 134s 179ms/step - loss: 2.8048 - accuracy: 0.4816 - val_loss: 2.3458 - val_accuracy: 0.5831
# Epoch 28/200
# 750/750 [==============================] - 132s 176ms/step - loss: 2.7809 - accuracy: 0.4848 - val_loss: 2.3189 - val_accuracy: 0.5858
# Epoch 29/200
# 750/750 [==============================] - 130s 174ms/step - loss: 2.7523 - accuracy: 0.4926 - val_loss: 2.3211 - val_accuracy: 0.5873
# Epoch 30/200
# 750/750 [==============================] - 131s 175ms/step - loss: 2.7411 - accuracy: 0.4937 - val_loss: 2.2841 - val_accuracy: 0.5923
# Epoch 31/200
# 750/750 [==============================] - 130s 174ms/step - loss: 2.7288 - accuracy: 0.4956 - val_loss: 2.3718 - val_accuracy: 0.5727
# Epoch 32/200
# 750/750 [==============================] - 134s 178ms/step - loss: 2.7049 - accuracy: 0.5007 - val_loss: 2.2424 - val_accuracy: 0.6021
# Epoch 33/200
# 750/750 [==============================] - 130s 173ms/step - loss: 2.6810 - accuracy: 0.5051 - val_loss: 2.2994 - val_accuracy: 0.5935
# Epoch 34/200
# 750/750 [==============================] - 133s 177ms/step - loss: 2.6692 - accuracy: 0.5082 - val_loss: 2.2432 - val_accuracy: 0.6040
# Epoch 35/200
# 750/750 [==============================] - 134s 178ms/step - loss: 2.6583 - accuracy: 0.5094 - val_loss: 2.2670 - val_accuracy: 0.5960
# Epoch 36/200
# 750/750 [==============================] - 133s 177ms/step - loss: 2.6385 - accuracy: 0.5119 - val_loss: 2.2118 - val_accuracy: 0.6109
# Epoch 37/200
# 750/750 [==============================] - 132s 175ms/step - loss: 2.6206 - accuracy: 0.5175 - val_loss: 2.3253 - val_accuracy: 0.5842
# Epoch 38/200
# 750/750 [==============================] - 133s 177ms/step - loss: 2.6111 - accuracy: 0.5201 - val_loss: 2.1738 - val_accuracy: 0.6177
# Epoch 39/200
# 750/750 [==============================] - 132s 177ms/step - loss: 2.5980 - accuracy: 0.5219 - val_loss: 2.2048 - val_accuracy: 0.6124
# Epoch 40/200
# 750/750 [==============================] - 132s 176ms/step - loss: 2.5849 - accuracy: 0.5249 - val_loss: 2.2155 - val_accuracy: 0.6108
# Epoch 41/200
# 750/750 [==============================] - 132s 176ms/step - loss: 2.5654 - accuracy: 0.5291 - val_loss: 2.1906 - val_accuracy: 0.6171
# Epoch 42/200
# 750/750 [==============================] - 133s 177ms/step - loss: 2.5610 - accuracy: 0.5303 - val_loss: 2.2094 - val_accuracy: 0.6092
# Epoch 43/200
# 750/750 [==============================] - 133s 178ms/step - loss: 2.5423 - accuracy: 0.5320 - val_loss: 2.1809 - val_accuracy: 0.6182
# Epoch 44/200
# 750/750 [==============================] - 131s 175ms/step - loss: 2.5349 - accuracy: 0.5345 - val_loss: 2.2268 - val_accuracy: 0.6087
# Epoch 45/200
# 750/750 [==============================] - 132s 176ms/step - loss: 2.5222 - accuracy: 0.5385 - val_loss: 2.1636 - val_accuracy: 0.6228
# Epoch 46/200
# 750/750 [==============================] - 134s 179ms/step - loss: 2.5118 - accuracy: 0.5405 - val_loss: 2.1848 - val_accuracy: 0.6176
# Epoch 47/200
# 750/750 [==============================] - 133s 177ms/step - loss: 2.5097 - accuracy: 0.5399 - val_loss: 2.1680 - val_accuracy: 0.6235
# Epoch 48/200
# 750/750 [==============================] - 135s 180ms/step - loss: 2.5003 - accuracy: 0.5420 - val_loss: 2.1263 - val_accuracy: 0.6320
# Epoch 49/200
# 750/750 [==============================] - 135s 180ms/step - loss: 2.4849 - accuracy: 0.5440 - val_loss: 2.1823 - val_accuracy: 0.6157
# Epoch 50/200
# 750/750 [==============================] - 135s 180ms/step - loss: 2.4727 - accuracy: 0.5463 - val_loss: 2.1158 - val_accuracy: 0.6330
# Epoch 51/200
# 750/750 [==============================] - 133s 178ms/step - loss: 2.4562 - accuracy: 0.5495 - val_loss: 2.1370 - val_accuracy: 0.6268
# Epoch 52/200
# 750/750 [==============================] - 132s 176ms/step - loss: 2.4576 - accuracy: 0.5494 - val_loss: 2.1297 - val_accuracy: 0.6291
# Epoch 53/200
# 750/750 [==============================] - 135s 180ms/step - loss: 2.4490 - accuracy: 0.5526 - val_loss: 2.1493 - val_accuracy: 0.6251
# Epoch 54/200
# 750/750 [==============================] - 132s 175ms/step - loss: 2.4369 - accuracy: 0.5542 - val_loss: 2.1120 - val_accuracy: 0.6317
# Epoch 55/200
# 750/750 [==============================] - 133s 178ms/step - loss: 2.4240 - accuracy: 0.5562 - val_loss: 2.1758 - val_accuracy: 0.6242
# Epoch 56/200
# 750/750 [==============================] - 133s 177ms/step - loss: 2.4178 - accuracy: 0.5566 - val_loss: 2.1383 - val_accuracy: 0.6290
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
import pandas as pd
pd.DataFrame(history.history).plot(figsize=(8,5))
plt.show()

# %%
gc.collect()
# Out:
# 54645

# %% [markdown]
# # 6. Saving model

# %%
from tensorflow.keras.models import save_model
save_model(model,"CNN.h5")

# %% [markdown]
# # 7. Testing the model

# %%
test = pd.read_csv('../input/quickdraw-doodle-recognition/test_simplified.csv', index_col="key_id" ,nrows=100)
ids = test.index
imagebag = bag.from_sequence(test.drawing.values).map(drawStrokes)
test_simplified = np.array(imagebag.compute())
test_simplified = test_simplified.reshape(len(test_simplified), 32, 32, 3)

# %%
del imagebag
gc.collect()
# Out:
# 21

# %%
prediction = model.predict(test_simplified)
indexOfBigProbability = (-prediction).argsort()[:,:4]
# Out:
# 4/4 [==============================] - 2s 169ms/step

# %%
gc.collect()
# Out:
# 1967

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import ast
import warnings
warnings.filterwarnings('ignore')

raw_images = [ast.literal_eval(lst) for lst in test.loc[test.iloc[:40].index, 'drawing'].values]

j=0

for index, raw_drawing in enumerate(raw_images):
    plt.figure(figsize=(3,3));
    for x,y in raw_drawing:
        title_obj=plt.title(Y.columns[indexOfBigProbability][j][0]
                  +" / "
                 +Y.columns[indexOfBigProbability][j][1]
                  +" / "
                 +Y.columns[indexOfBigProbability][j][2]
                  +" / "
                 +Y.columns[indexOfBigProbability][j][3], fontsize=22)
        plt.subplot(1, 1, 1);
        plt.plot(x,y);
        plt.axis('off');
    plt.gca().invert_yaxis();
    j+=1;

# %% [markdown]
# # Training Documentation

# %% [markdown]
# ## model with regularization
# ![image.png](attachment:70a61ffd-636e-40d9-be85-e40de8571484.png)
#
# ## model with data augmentation
# ![image.png](attachment:eddd6683-c84e-4047-bc5d-59f8cbd5fa21.png)
#
# ## complex model with data aug.
# ![image.png](attachment:28eb6506-aeea-473d-ba40-cc46e10b2398.png)
#
# ![image.png](attachment:37075b3f-a703-4006-bb9c-e22734db40ae.png)
#
# ## 4 Dense Layers
# ![image.png](attachment:06aa242c-49de-430f-bbd5-901c68bd96c2.png)

# %% [markdown]
# # Session hardware status :
# ![image.png](attachment:bb5f7f0d-695d-4074-b147-5d666c1ca492.png)
