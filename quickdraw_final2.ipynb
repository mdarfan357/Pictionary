# %% [markdown]
# # 0. Data Importing from kaggle

# %%
import os
from tqdm.notebook import tqdm
for dirname, _, filenames in tqdm(os.walk('/kaggle/input')):
    for filename in filenames:
        os.path.join(dirname, filename)
#         print(os.path.join(dirname, filename))
# Out:
# 0it [00:00, ?it/s]

# %% [markdown]
# # Limiting GPU usage

# %%
# limit memory to prevent data leak
import tensorflow as tf
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    
    del logical_gpus,gpus
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# 2 Physical GPUs, 2 Logical GPUs

# %% [markdown]
# # 1. Importing modules

# %%
import numpy as np
import pandas as pd
import json
import gc
import matplotlib.pyplot as plt
# %matplotlib inline
from glob import glob
import os
train_files = glob("../input/quickdraw-doodle-recognition/train_simplified/*.csv")

# calculating data size per category
rows = 200000
# rows = 10000
rows = rows - (rows % 340)
cat_size = rows // 340
print(cat_size)
gc.collect()
# Out:
# 588
# 56

# %% [markdown]
# # 2. Image Preprocessing
# 1. converting data in text json to an image
# 2. normalizing the image size
# 3. normalizing the image pixels

# %%
from PIL import Image, ImageDraw
from dask import bag
def drawStrokes(matrixOfStrokes):
    image = Image.new("RGB", (256,256), color=255)
    image_draw = ImageDraw.Draw(image)
    for stroke in json.loads(matrixOfStrokes):
        for i in range(len(stroke[0])-1):
            image_draw.line([stroke[0][i], 
                             stroke[1][i],
                             stroke[0][i+1], 
                             stroke[1][i+1]],
                            fill=0, width=5)
    return np.array(image.resize((32,32)))/255.

# %%
from tqdm.notebook import tqdm
X = np.zeros((rows,32,32,3))
categories = pd.Series([None] * rows)
i = 0
for f in tqdm(train_files):
    for df in pd.read_csv(f, index_col="key_id", chunksize=1000, nrows=cat_size):
        df = df.drop(['countrycode','timestamp','recognized'],axis=1)
        imagebag = bag.from_sequence(df.drawing.values).map(drawStrokes)
        imagebag = np.array(imagebag.compute())
        categories[i:(i + imagebag.shape[0])] = df["word"].replace("\s+", "_", regex=True)
        X[i:(i + imagebag.shape[0])] = imagebag
        i += imagebag.shape[0]
# Out:
#   0%|          | 0/340 [00:00<?, ?it/s]

# %%
gc.collect()
# Out:
# 39

# %%
categories.value_counts()
# Out:
# traffic_light    588
# umbrella         588
# house            588
# trombone         588
# paper_clip       588
#                 ...
# rain             588
# rabbit           588
# lantern          588
# toaster          588
# fish             588
# Length: 340, dtype: int64

# %% [markdown]
# # 3. Train Test split

# %%
from sklearn.model_selection import train_test_split
Y = pd.get_dummies(categories)
tr_x,tst_x,tr_Y,tst_Y = train_test_split(X, Y, test_size=0.25,random_state=25,stratify=Y)

# %%
itr = 0
for df in tr_Y:
    print(f"{df} : {tr_Y[df].value_counts()[1]}")
    if itr == 5:
        break
    else:
        itr+= 1
# Out:
# The_Eiffel_Tower : 441
# The_Great_Wall_of_China : 441
# The_Mona_Lisa : 441
# airplane : 441
# alarm_clock : 441
# ambulance : 441

# %%
itr = 0
for df in tst_Y:
    try:
        print(f"{df} : {tst_Y[df].value_counts()[1]}")
    except:
        print(f"{df} : 0")
        
    if itr == 5:
        break
    else:
        itr+= 1
# Out:
# The_Eiffel_Tower : 147
# The_Great_Wall_of_China : 147
# The_Mona_Lisa : 147
# airplane : 147
# alarm_clock : 147
# ambulance : 147

# %%
del X,categories
gc.collect()
# Out:
# 21

# %% [markdown]
# # 4. Creating Deep learning model
#
# changed state to 25

# %%
from keras.callbacks import ModelCheckpoint
# from tensorflow.keras.optimizers.legacy import Adam

filepath = 'my_best_model.h5'

checkpoint = ModelCheckpoint(filepath=filepath, 
                             monitor="val_accuracy", 
                             save_best_only=True,
                             mode='min')

# %%
from keras.callbacks import EarlyStopping
earlystop= EarlyStopping(monitor='val_accuracy', patience=6)

# %%
callbacks = [checkpoint,earlystop]

# %%
gc.collect()
# Out:
# 84

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import *
from tensorflow.keras import regularizers

strategy = tf.distribute.MirroredStrategy()
    
with strategy.scope():
    model = Sequential()
    model.add(Conv2D(128,kernel_size=(5,5),padding="same",activation="relu",input_shape=(32,32,3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(BatchNormalization())

    model.add(Conv2D(128, kernel_size=(4,4), strides=1))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(BatchNormalization())

    model.add(Conv2D(64, kernel_size=(3,3), strides=1))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(BatchNormalization())

    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dropout(0.25))
    model.add(BatchNormalization())
    
    model.add(Dense(340))
    model.add(Activation('softmax'))

    model.compile(loss='categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 128)       9728
#
#  activation (Activation)     (None, 32, 32, 128)       0
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 128)      0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 128)       0
#
#  batch_normalization (BatchN  (None, 16, 16, 128)      512
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 128)       262272
#
#  activation_1 (Activation)   (None, 13, 13, 128)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 128)         0
#
#  batch_normalization_1 (Batc  (None, 6, 6, 128)        512
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 64)          73792
#
#  activation_2 (Activation)   (None, 4, 4, 64)          0
#
#  max_pooling2d_2 (MaxPooling  (None, 2, 2, 64)         0
#  2D)
#
#  dropout_2 (Dropout)         (None, 2, 2, 64)          0
#
#  batch_normalization_2 (Batc  (None, 2, 2, 64)         256
#  hNormalization)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 1024)              263168
#
#  activation_3 (Activation)   (None, 1024)              0
#
#  batch_normalization_3 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  activation_4 (Activation)   (None, 512)               0
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  batch_normalization_4 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_2 (Dense)             (None, 340)               174420
#
#  activation_5 (Activation)   (None, 340)               0
#
# =================================================================
# Total params: 1,315,604
# Trainable params: 1,311,892
# Non-trainable params: 3,712
# _________________________________________________________________

# %%
gc.collect()
# Out:
# 1359

# %% [markdown]
# # 6. Data Augmentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

batch_size = 200
aug = ImageDataGenerator(
        rotation_range=20,
        zoom_range=0.15,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.15,
        horizontal_flip=True,
        fill_mode="nearest")

# %% [markdown]
# # 5. Training Deep learning model

# %% [markdown]
# RUN 1

# %%
# history = model.fit(tr_x, tr_Y,batch_size=200,epochs=200
#           ,validation_data=(tst_x,tst_Y),callbacks=callbacks)

# history = model.fit(tr_x, tr_Y,batch_size=128,epochs=30
#           ,validation_data=(tst_x,tst_Y))

# history = model.fit(
#     x=aug.flow(tr_x, tr_Y, batch_size=batch_size),
#     validation_data=(tst_x,tst_Y),
#     epochs=30,
#     callbacks=callbacks)

history = model.fit(
    x=aug.flow(tr_x, tr_Y, batch_size=batch_size),
    validation_data=(tst_x,tst_Y),
    epochs=200,
    callbacks=callbacks)

print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.grid()
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.grid()
plt.show()
# Out:
# Epoch 1/200
# 2023-04-02 10:17:41.883484: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 750/750 [==============================] - 134s 153ms/step - loss: 5.4222 - accuracy: 0.0291 - val_loss: 10.4213 - val_accuracy: 0.0063
# Epoch 2/200
# 750/750 [==============================] - 111s 147ms/step - loss: 4.4997 - accuracy: 0.0939 - val_loss: 3.8411 - val_accuracy: 0.1785
# Epoch 3/200
# 750/750 [==============================] - 118s 157ms/step - loss: 4.0837 - accuracy: 0.1456 - val_loss: 4.3580 - val_accuracy: 0.1300
# Epoch 4/200
# 750/750 [==============================] - 120s 160ms/step - loss: 3.8411 - accuracy: 0.1794 - val_loss: 3.1852 - val_accuracy: 0.2908
# Epoch 5/200
# 750/750 [==============================] - 111s 148ms/step - loss: 3.6911 - accuracy: 0.2041 - val_loss: 4.0630 - val_accuracy: 0.1944
# Epoch 6/200
# 750/750 [==============================] - 109s 146ms/step - loss: 3.5839 - accuracy: 0.2201 - val_loss: 3.2387 - val_accuracy: 0.2700
# Epoch 7/200
# 750/750 [==============================] - 118s 157ms/step - loss: 3.4947 - accuracy: 0.2328 - val_loss: 2.7987 - val_accuracy: 0.3574
# Epoch 27/200
# 750/750 [==============================] - 110s 147ms/step - loss: 2.9792 - accuracy: 0.3223 - val_loss: 2.1519 - val_accuracy: 0.4899
# Epoch 28/200
# 750/750 [==============================] - 110s 146ms/step - loss: 2.9706 - accuracy: 0.3233 - val_loss: 2.3564 - val_accuracy: 0.4478
# Epoch 29/200
# 750/750 [==============================] - 110s 147ms/step - loss: 2.9594 - accuracy: 0.3244 - val_loss: 2.2136 - val_accuracy: 0.4766
# Epoch 30/200
# 750/750 [==============================] - 118s 157ms/step - loss: 2.9496 - accuracy: 0.3280 - val_loss: 2.5404 - val_accuracy: 0.4120
# Epoch 31/200
# 750/750 [==============================] - 118s 157ms/step - loss: 2.9355 - accuracy: 0.3296 - val_loss: 3.0484 - val_accuracy: 0.3351
# Epoch 32/200
# 750/750 [==============================] - 117s 156ms/step - loss: 2.9220 - accuracy: 0.3313 - val_loss: 2.1258 - val_accuracy: 0.4943
# Epoch 33/200
# 750/750 [==============================] - 109s 145ms/step - loss: 2.9220 - accuracy: 0.3312 - val_loss: 2.3659 - val_accuracy: 0.4430
# Epoch 34/200
# 750/750 [==============================] - 117s 157ms/step - loss: 2.9150 - accuracy: 0.3322 - val_loss: 2.1468 - val_accuracy: 0.4935
# Epoch 35/200
# 750/750 [==============================] - 117s 156ms/step - loss: 2.9021 - accuracy: 0.3353 - val_loss: 2.1431 - val_accuracy: 0.4907
# Epoch 36/200
# 750/750 [==============================] - 110s 146ms/step - loss: 2.8956 - accuracy: 0.3362 - val_loss: 2.5253 - val_accuracy: 0.4137
# Epoch 37/200
# 750/750 [==============================] - 109s 146ms/step - loss: 2.8912 - accuracy: 0.3368 - val_loss: 2.2047 - val_accuracy: 0.4785
# Epoch 38/200
# 750/750 [==============================] - 111s 147ms/step - loss: 2.8827 - accuracy: 0.3383 - val_loss: 2.2982 - val_accuracy: 0.4563
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
import pandas as pd
pd.DataFrame(history.history).plot(figsize=(8,5))
plt.show()

# %%
gc.collect()
# Out:
# 29900

# %% [markdown]
# # 6. Saving model

# %%
from tensorflow.keras.models import save_model
save_model(model,"CNN.h5")

# %% [markdown]
# # 7. Testing the model

# %%
del model
gc.collect()
# Out:
# 21

# %%
from tensorflow.keras.models import load_model
model = load_model("my_best_model.h5")

# %%
test = pd.read_csv('../input/quickdraw-doodle-recognition/test_simplified.csv', index_col="key_id" ,nrows=100)
ids = test.index
imagebag = bag.from_sequence(test.drawing.values).map(drawStrokes)
test_simplified = np.array(imagebag.compute())
test_simplified = test_simplified.reshape(len(test_simplified), 32, 32, 3)

# %%
del imagebag
gc.collect()
# Out:
# 21

# %%
prediction = model.predict(test_simplified)
indexOfBigProbability = (-prediction).argsort()[:,:4]
# Out:
# 4/4 [==============================] - 0s 27ms/step

# %%
gc.collect()
# Out:
# 721

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import ast
import warnings
warnings.filterwarnings('ignore')

raw_images = [ast.literal_eval(lst) for lst in test.loc[test.iloc[:40].index, 'drawing'].values]

j=0

for index, raw_drawing in enumerate(raw_images):
    plt.figure(figsize=(3,3));
    for x,y in raw_drawing:
        title_obj=plt.title(Y.columns[indexOfBigProbability][j][0]
                  +" / "
                 +Y.columns[indexOfBigProbability][j][1]
                  +" / "
                 +Y.columns[indexOfBigProbability][j][2]
                  +" / "
                 +Y.columns[indexOfBigProbability][j][3], fontsize=22)
        plt.subplot(1, 1, 1);
        plt.plot(x,y);
        plt.axis('off');
    plt.gca().invert_yaxis();
    j+=1;

# %% [markdown]
# # Training Documentation

# %% [markdown]
# ## model with regularization
# ![image.png](attachment:70a61ffd-636e-40d9-be85-e40de8571484.png)
#
# ## model with data augmentation
# ![image.png](attachment:eddd6683-c84e-4047-bc5d-59f8cbd5fa21.png)
#
# ## complex model with data aug.
# ![image.png](attachment:28eb6506-aeea-473d-ba40-cc46e10b2398.png)
#
# ![image.png](attachment:37075b3f-a703-4006-bb9c-e22734db40ae.png)
#
# ## 4 Dense Layers
# ![image.png](attachment:06aa242c-49de-430f-bbd5-901c68bd96c2.png)

# %% [markdown]
# # Session hardware status :
# ![image.png](attachment:bb5f7f0d-695d-4074-b147-5d666c1ca492.png)
