# %% [markdown]
# # 0. Data Importing from kaggle

# %%
import os
from tqdm.notebook import tqdm
for dirname, _, filenames in tqdm(os.walk('/kaggle/input')):
    for filename in filenames:
        os.path.join(dirname, filename)
#         print(os.path.join(dirname, filename))
# Out:
# 0it [00:00, ?it/s]

# %% [markdown]
# # Limiting GPU usage

# %%
# limit memory to prevent data leak
import tensorflow as tf
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    
    del logical_gpus,gpus
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# 2 Physical GPUs, 2 Logical GPUs

# %% [markdown]
# # 1. Importing modules

# %%
import numpy as np
import pandas as pd
import json
import gc
import matplotlib.pyplot as plt
# %matplotlib inline
from glob import glob
import os
train_files = glob("../input/quickdraw-doodle-recognition/train_simplified/*.csv")
testing = False
# calculating data size per category
rows = 200000

if testing:
    rows = 10000 # testing

rows = rows - (rows % 340)
cat_size = rows // 340
print(cat_size)
gc.collect()
# Out:
# 588
# 56

# %% [markdown]
# # 2. Data Importing and Image Preprocessing
# 1. Data Importing and Removing unwanted columns
# 2. converting data in text json to an image
# 3. normalizing the image size
# 4. normalizing the image pixels

# %%
from PIL import Image, ImageDraw
from dask import bag
def drawStrokes(matrixOfStrokes):
    image = Image.new("RGB", (256,256), color=255)
    image_draw = ImageDraw.Draw(image)
    for stroke in json.loads(matrixOfStrokes):
        for i in range(len(stroke[0])-1):
            image_draw.line([stroke[0][i], 
                             stroke[1][i],
                             stroke[0][i+1], 
                             stroke[1][i+1]],
                            fill=0, width=5)
    return np.array(image.resize((32,32)))/255.

# %%
from tqdm.notebook import tqdm
X = np.zeros((rows,32,32,3))
categories = pd.Series([None] * rows)
i = 0
for f in tqdm(train_files):
    for df in pd.read_csv(f, index_col="key_id", chunksize=1000, nrows=cat_size):
        df = df.drop(['countrycode','timestamp','recognized'],axis=1)
        imagebag = bag.from_sequence(df.drawing.values).map(drawStrokes)
        imagebag = np.array(imagebag.compute())
        categories[i:(i + imagebag.shape[0])] = df["word"].replace("\s+", "_", regex=True)
        X[i:(i + imagebag.shape[0])] = imagebag
        i += imagebag.shape[0]
# Out:
#   0%|          | 0/340 [00:00<?, ?it/s]

# %%
gc.collect()
# Out:
# 39

# %%
categories.value_counts()
# Out:
# traffic_light    588
# umbrella         588
# house            588
# trombone         588
# paper_clip       588
#                 ...
# rain             588
# rabbit           588
# lantern          588
# toaster          588
# fish             588
# Length: 340, dtype: int64

# %% [markdown]
# # 3. Train Test split

# %%
from sklearn.model_selection import train_test_split
Y = pd.get_dummies(categories)
tr_x,tst_x,tr_Y,tst_Y = train_test_split(X, Y, test_size=0.25,shuffle=True,stratify=Y)

# %%
itr = 0
for df in tr_Y:
    print(f"{df} : {tr_Y[df].value_counts()[1]}")
    if itr == 5:
        break
    else:
        itr+= 1
# Out:
# The_Eiffel_Tower : 441
# The_Great_Wall_of_China : 441
# The_Mona_Lisa : 441
# airplane : 441
# alarm_clock : 441
# ambulance : 441

# %%
itr = 0
for df in tst_Y:
    try:
        print(f"{df} : {tst_Y[df].value_counts()[1]}")
    except:
        print(f"{df} : 0")
        
    if itr == 5:
        break
    else:
        itr+= 1
# Out:
# The_Eiffel_Tower : 147
# The_Great_Wall_of_China : 147
# The_Mona_Lisa : 147
# airplane : 147
# alarm_clock : 147
# ambulance : 147

# %%
del X,categories
gc.collect()
# Out:
# 63

# %% [markdown]
# # 4. Creating Deep learning model
#
# - model choosen for problem statement is a CNN
# - additionally we also need to add an EarlyStopping to prevent overfitting and ModelCheckpoint to save the best model as callback
# - model uses categorical crossentropy to calculate loss and Adam as an optimizer

# %%
from keras.callbacks import ModelCheckpoint
# from tensorflow.keras.optimizers.legacy import Adam

filepath = 'my_best_model.h5'

checkpoint = ModelCheckpoint(filepath=filepath, 
                             monitor="val_accuracy", 
                             save_best_only=True,
                             mode='min')

# %%
from keras.callbacks import EarlyStopping
earlystop= EarlyStopping(monitor='val_accuracy', patience=6)

# %%
# callbacks = [checkpoint,earlystop]
callbacks = [checkpoint]

# %%
gc.collect()
# Out:
# 84

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import *
from tensorflow.keras import regularizers
import keras

strategy = tf.distribute.MirroredStrategy()
with strategy.scope():
    
    model = Sequential()
    
    model.add(Conv2D(32, (3, 3), input_shape=(32,32,3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(BatchNormalization())

    model.add(Conv2D(32, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(BatchNormalization())

    model.add(Conv2D(64, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    
    model.add(Flatten())

    
    model.add(Dense(1024, activation='relu',kernel_regularizer=regularizers.l2(0.05)))
#     model.add(Dense(1024, activation='relu'))
    model.add(Dropout(0.5))
    model.add(BatchNormalization())

#     model.add(Dense(512, activation='relu'))
    model.add(Dense(1024, activation='relu',kernel_regularizer=regularizers.l2(0.01)))
    model.add(Dropout(0.5))
    model.add(BatchNormalization())

    model.add(Dense(340, activation='softmax'))
    
    model.compile(loss='categorical_crossentropy',
              optimizer=keras.optimizers.Adam(1e-5),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 32)        896
#
#  activation (Activation)     (None, 30, 30, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 32)       0
#  )
#
#  batch_normalization (BatchN  (None, 15, 15, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 32)        9248
#
#  activation_1 (Activation)   (None, 13, 13, 32)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 32)         0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 6, 6, 32)         128
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 64)          18496
#
#  activation_2 (Activation)   (None, 4, 4, 64)          0
#
#  max_pooling2d_2 (MaxPooling  (None, 2, 2, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 1024)              263168
#
#  dropout (Dropout)           (None, 1024)              0
#
#  batch_normalization_2 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dense_1 (Dense)             (None, 1024)              1049600
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  batch_normalization_3 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dense_2 (Dense)             (None, 340)               348500
#
# =================================================================
# Total params: 1,698,356
# Trainable params: 1,694,132
# Non-trainable params: 4,224
# _________________________________________________________________

# %%
gc.collect()
# Out:
# 753

# %% [markdown]
# # 6. Data Augmentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

def to_grayscale_then_rgb(image):
    image = tf.image.rgb_to_grayscale(image)
    image = tf.image.grayscale_to_rgb(image)
    return image

batch_size = 128
aug = ImageDataGenerator(
        rotation_range=20,
#         preprocessing_function=to_grayscale_then_rgb,
        zoom_range=0.15,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.15,
        horizontal_flip=True,
        fill_mode="nearest")

test_aug = ImageDataGenerator(
        preprocessing_function=to_grayscale_then_rgb)

# %% [markdown]
# # 5. Training Deep learning model

# %% [markdown]
# RUN 1

# %%
if testing == True:
    history = model.fit(
        x=aug.flow(tr_x, tr_Y, batch_size=batch_size),
        validation_data=(tst_x,tst_Y),
        epochs=30,
        shuffle = True,
        callbacks=callbacks)
else:
    history = model.fit(
        x=aug.flow(tr_x, tr_Y, batch_size=batch_size,shuffle=True),
        validation_data=(tst_x,tst_Y),
        epochs=100,
        callbacks=callbacks)

print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.grid()
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.grid()
plt.show()
# Out:
# Epoch 1/100
# 1172/1172 [==============================] - 119s 86ms/step - loss: 34.1849 - accuracy: 0.0034 - val_loss: 30.8268 - val_accuracy: 0.0080
# Epoch 2/100
# 1172/1172 [==============================] - 99s 85ms/step - loss: 29.0073 - accuracy: 0.0051 - val_loss: 26.2577 - val_accuracy: 0.0139
# Epoch 3/100
# 1172/1172 [==============================] - 100s 85ms/step - loss: 24.9846 - accuracy: 0.0072 - val_loss: 22.6867 - val_accuracy: 0.0184
# Epoch 4/100
# 1172/1172 [==============================] - 98s 83ms/step - loss: 21.7984 - accuracy: 0.0092 - val_loss: 19.8553 - val_accuracy: 0.0247
# Epoch 5/100
# 1172/1172 [==============================] - 107s 91ms/step - loss: 19.2698 - accuracy: 0.0104 - val_loss: 17.5835 - val_accuracy: 0.0311
# Epoch 6/100
# 1172/1172 [==============================] - 111s 95ms/step - loss: 17.2180 - accuracy: 0.0124 - val_loss: 15.7281 - val_accuracy: 0.0405
# Epoch 7/100
# 1172/1172 [==============================] - 111s 95ms/step - loss: 15.5523 - accuracy: 0.0142 - val_loss: 14.2158 - val_accuracy: 0.0475
# Epoch 8/100
# 1172/1172 [==============================] - 112s 95ms/step - loss: 14.1700 - accuracy: 0.0171 - val_loss: 12.9602 - val_accuracy: 0.0538
# Epoch 9/100
# 1172/1172 [==============================] - 107s 92ms/step - loss: 13.0179 - accuracy: 0.0195 - val_loss: 11.9047 - val_accuracy: 0.0616
# Epoch 10/100
100
# 1172/1172 [==============================] - 94s 80ms/step - loss: 4.2740 - accuracy: 0.1741 - val_loss: 3.6349 - val_accuracy: 0.2813
# Epoch 59/100
# 1172/1172 [==============================] - 95s 81ms/step - loss: 4.2554 - accuracy: 0.1765 - val_loss: 3.6186 - val_accuracy: 0.2845
# Epoch 60/100
# 1172/1172 [==============================] - 96s 82ms/step - loss: 4.2326 - accuracy: 0.1774 - val_loss: 3.5674 - val_accuracy: 0.2910
# Epoch 61/100
# 1172/1172 [==============================] - 95s 81ms/step - loss: 4.2081 - accuracy: 0.1808 - val_loss: 3.5582 - val_accuracy: 0.2916
# Epoch 62/100
# 1172/1172 [==============================] - 95s 81ms/step - loss: 4.1762 - accuracy: 0.1827 - val_loss: 3.5708 - val_accuracy: 0.2894
# Epoch 63/100
# 1172/1172 [==============================] - 94s 80ms/step - loss: 4.1569 - accuracy: 0.1851 - val_loss: 3.5335 - val_accuracy: 0.2908
# Epoch 64/100
# 1172/1172 [==============================] - 95s 81ms/step - loss: 4.1310 - accuracy: 0.1891 - val_loss: 3.5272 - val_accuracy: 0.2914
# Epoch 65/100
# 1172/1172 [==============================] - 95s 81ms/step - loss: 4.1153 - accuracy: 0.1911 - val_loss: 3.4750 - val_accuracy: 0.2999
# Epoch 66/100
# 1172/1172 [==============================] - 94s 80ms/step - loss: 4.0992 - accuracy: 0.1909 - val_loss: 3.4578 - val_accuracy: 0.2991
# Epoch 67/100
# 1172/1172 [==============================] - 94s 80ms/step - loss: 4.0781 - accuracy: 0.1940 - val_loss: 3.4764 - val_accuracy: 0.2952
# Epoch 68/100
# 1172/1172 [==============================] - 95s 81ms/step - loss: 4.0512 - accuracy: 0.1962 - val_loss: 3.4349 - val_accuracy: 0.3031
# Epoch 69/100
# 1172/1172 [==============================] - 96s 81ms/step - loss: 4.0326 - accuracy: 0.1971 - val_loss: 3.4141 - val_accuracy: 0.3058
# Epoch 70/100
# 1172/1172 [==============================] - 98s 84ms/step - loss: 4.0230 - accuracy: 0.1983 - val_loss: 3.4197 - val_accuracy: 0.3021
# Epoch 71/100
# 1172/1172 [==============================] - 94s 80ms/step - loss: 3.9991 - accuracy: 0.1995 - val_loss: 3.4130 - val_accuracy: 0.3045
# Epoch 72/100
# 1172/1172 [==============================] - 95s 81ms/step - loss: 3.9846 - accuracy: 0.2032 - val_loss: 3.3967 - val_accuracy: 0.3049
# Epoch 73/100
# 1172/1172 [==============================] - 95s 81ms/step - loss: 3.9652 - accuracy: 0.2033 - val_loss: 3.3301 - val_accuracy: 0.3152
# Epoch 74/100
# 1172/1172 [==============================] - 95s 81ms/step - loss: 3.9474 - accuracy: 0.2058 - val_loss: 3.3606 - val_accuracy: 0.3098
# Epoch 75/100
# 1172/1172 [==============================] - 95s 81ms/step - loss: 3.9307 - accuracy: 0.2087 - val_loss: 3.3452 - val_accuracy: 0.3131
# Epoch 76/100
# 1172/1172 [==============================] - 94s 81ms/step - loss: 3.9168 - accuracy: 0.2096 - val_loss: 3.3270 - val_accuracy: 0.3115
# Epoch 77/100
# 1172/1172 [==============================] - 95s 81ms/step - loss: 3.8993 - accuracy: 0.2119 - val_loss: 3.3086 - val_accuracy: 0.3174
# Epoch 78/100
# 1172/1172 [==============================] - 95s 81ms/step - loss: 3.8886 - accuracy: 0.2138 - val_loss: 3.3026 - val_accuracy: 0.3179
# Epoch 79/100
# 1172/1172 [==============================] - 95s 81ms/step - loss: 3.8747 - accuracy: 0.2147 - val_loss: 3.2365 - val_accuracy: 0.3278
# Epoch 80/100
# 1172/1172 [==============================] - 97s 82ms/step - loss: 3.8588 - accuracy: 0.2166 - val_loss: 3.2836 - val_accuracy: 0.3172
# Epoch 81/100
# 1172/1172 [==============================] - 95s 81ms/step - loss: 3.8536 - accuracy: 0.2147 - val_loss: 3.2817 - val_accuracy: 0.3192
# Epoch 82/100
# 1172/1172 [==============================] - 95s 81ms/step - loss: 3.8322 - accuracy: 0.2193 - val_loss: 3.2521 - val_accuracy: 0.3235
# Epoch 83/100
# 1172/1172 [==============================] - 96s 82ms/step - loss: 3.8242 - accuracy: 0.2201 - val_loss: 3.2236 - val_accuracy: 0.3280
# Epoch 84/100
# 1172/1172 [==============================] - 94s 80ms/step - loss: 3.8123 - accuracy: 0.2221 - val_loss: 3.2099 - val_accuracy: 0.3294
# Epoch 85/100
# 1172/1172 [==============================] - 94s 81ms/step - loss: 3.7975 - accuracy: 0.2236 - val_loss: 3.1706 - val_accuracy: 0.3353
# Epoch 86/100
# 1172/1172 [==============================] - 95s 81ms/step - loss: 3.7891 - accuracy: 0.2236 - val_loss: 3.2000 - val_accuracy: 0.3297
# Epoch 87/100
# 1172/1172 [==============================] - 94s 80ms/step - loss: 3.7797 - accuracy: 0.2256 - val_loss: 3.1924 - val_accuracy: 0.3313
# Epoch 88/100
# 1172/1172 [==============================] - 94s 80ms/step - loss: 3.7695 - accuracy: 0.2262 - val_loss: 3.1605 - val_accuracy: 0.3349
# Epoch 89/100
# 1172/1172 [==============================] - 95s 81ms/step - loss: 3.7548 - accuracy: 0.2298 - val_loss: 3.1366 - val_accuracy: 0.3400
# Epoch 90/100
# 1172/1172 [==============================] - 95s 81ms/step - loss: 3.7546 - accuracy: 0.2276 - val_loss: 3.1445 - val_accuracy: 0.3394
# Epoch 91/100
# 1172/1172 [==============================] - 111s 95ms/step - loss: 3.7376 - accuracy: 0.2291 - val_loss: 3.2035 - val_accuracy: 0.3276
# Epoch 92/100
# 1172/1172 [==============================] - 94s 81ms/step - loss: 3.7245 - accuracy: 0.2323 - val_loss: 3.1693 - val_accuracy: 0.3315
# Epoch 93/100
# 1172/1172 [==============================] - 95s 81ms/step - loss: 3.7182 - accuracy: 0.2325 - val_loss: 3.1471 - val_accuracy: 0.3377
# Epoch 94/100
# 1172/1172 [==============================] - 95s 81ms/step - loss: 3.7126 - accuracy: 0.2335 - val_loss: 3.1084 - val_accuracy: 0.3436
# Epoch 95/100
# 1172/1172 [==============================] - 96s 82ms/step - loss: 3.6989 - accuracy: 0.2349 - val_loss: 3.1556 - val_accuracy: 0.3340
# Epoch 96/100
# 1172/1172 [==============================] - 94s 80ms/step - loss: 3.6924 - accuracy: 0.2369 - val_loss: 3.1051 - val_accuracy: 0.3417
# Epoch 97/100
# 1172/1172 [==============================] - 95s 81ms/step - loss: 3.6838 - accuracy: 0.2373 - val_loss: 3.1255 - val_accuracy: 0.3393
# Epoch 98/100
# 1172/1172 [==============================] - 94s 80ms/step - loss: 3.6744 - accuracy: 0.2375 - val_loss: 3.1103 - val_accuracy: 0.3419
# Epoch 99/100
# 1172/1172 [==============================] - 94s 80ms/step - loss: 3.6710 - accuracy: 0.2389 - val_loss: 3.1158 - val_accuracy: 0.3408
# Epoch 100/100
# 1172/1172 [==============================] - 95s 81ms/step - loss: 3.6563 - accuracy: 0.2403 - val_loss: 3.1010 - val_accuracy: 0.3423
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
gc.collect()
# Out:
# 81233

# %% [markdown]
# # 6. Testing the model

# %%
del model
gc.collect()
# Out:
# 21

# %% [markdown]
# ## Loading saved model

# %%
from tensorflow.keras.models import load_model
model = load_model("my_best_model.h5")

# %% [markdown]
# ## Importing testing data

# %%
test = pd.read_csv('../input/quickdraw-doodle-recognition/test_simplified.csv', index_col="key_id" ,nrows=100)
ids = test.index
imagebag = bag.from_sequence(test.drawing.values).map(drawStrokes)
test_simplified = np.array(imagebag.compute())
test_simplified = test_simplified.reshape(len(test_simplified), 32, 32, 3)

# %%
del imagebag
gc.collect()
# Out:
# 21

# %% [markdown]
# ## Make predictions

# %%
prediction = model.predict(test_simplified)
indexOfBigProbability = (-prediction).argsort()[:,:4]
# Out:
# 4/4 [==============================] - 0s 26ms/step

# %%
gc.collect()
# Out:
# 721

# %% [markdown]
# ## Plotting the predictions

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import ast
import warnings
warnings.filterwarnings('ignore')

raw_images = [ast.literal_eval(lst) for lst in test.loc[test.iloc[:40].index, 'drawing'].values]

j=0

for index, raw_drawing in enumerate(raw_images):
    plt.figure(figsize=(3,3));
    for x,y in raw_drawing:
        title_obj=plt.title(Y.columns[indexOfBigProbability][j][0]
                  +" / "
                 +Y.columns[indexOfBigProbability][j][1]
                  +" / "
                 +Y.columns[indexOfBigProbability][j][2]
                  +" / "
                 +Y.columns[indexOfBigProbability][j][3], fontsize=22)
        plt.subplot(1, 1, 1);
        plt.plot(x,y);
        plt.axis('off');
    plt.gca().invert_yaxis();
    j+=1;
